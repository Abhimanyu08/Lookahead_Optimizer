# %%
from fastai import datasets
from utils import *
from callbacks import *
from optimizers import *
from data_block import *
from transforms import *
from xresnets import *
from learner import *
import torch.nn.functional as F

# %%
path = Path('C:/Users/iamab/Downloads/imagenette2-160')
path.ls()
# Out:
# [WindowsPath('C:/Users/iamab/Downloads/imagenette2-160/train'),
#  WindowsPath('C:/Users/iamab/Downloads/imagenette2-160/val'),
#  WindowsPath('C:/Users/iamab/Downloads/imagenette2-160/wandb')]

# %%
def grandparent_splitter(o,name): return True if o.parent.parent.name == name else False
def parent_name(o): return o.parent.name

# %%
tfms = [into_rgb, ResizeFixed(128), np_to_float, PIL_FLIP(0.5)]
il = ImageList.from_path(path, tfms = tfms)
sl = SplitDataset.from_func(il, partial(grandparent_splitter, name = 'val'))
ll = label_train_valid(sl, func = parent_name, procy= Processor())

# %%
data = ll.to_databunch(train_bs=64)

# %%
model = xresnet34(init_func = 'kaiming_normal_')

# %%
sched = combine_scheds(create_phases(0.2), cos_annealer(0.001,0.1,0.01))
cbfs = [CudaCallback, normalise_callback(data), partial(AvgStatsCallback, accuracy), NewRecorderCallback, 
        partial(NewParamSchedulerCallback, 'lr', sched), WandbCallback, ProgressCallback]

# %%
wandb.init(name = 'without_lookahead', project = 'learning',entity = 'a_bhimanyu',
           dir = 'C:/Users/iamab/Downloads/imagenette2-160')

opt = partial(StatefulOptimizer, 
              steppers = [momentum_step, weight_decay], 
              stats = [AverageGrad()], 
              lr =0.01,wd = 1e-04)

learn = Learner(model, data, loss_func=F.cross_entropy, opt_func=opt, cb_funcs=cbfs)
# Out:
#                 Logging results to <a href="https://wandb.com" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://app.wandb.ai/a_bhimanyu/learning" target="_blank">https://app.wandb.ai/a_bhimanyu/learning</a><br/>
#                 Run page: <a href="https://app.wandb.ai/a_bhimanyu/learning/runs/1xqv2t5t" target="_blank">https://app.wandb.ai/a_bhimanyu/learning/runs/1xqv2t5t</a><br/>
# W&B Run: https://app.wandb.ai/a_bhimanyu/learning/runs/1xqv2t5t

# %% [markdown]
# ## Learning without Lookahead

# %%
learn.fit(30)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='30', style='width:300px; height:20px; vertical-align: middle;'></progress>
#
#     </div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>train_accuracy</th>
#       <th>valid_loss</th>
#       <th>valid_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.109237</td>
#       <td>0.265392</td>
#       <td>2.177341</td>
#       <td>0.339873</td>
#       <td>04:20</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.052483</td>
#       <td>0.354842</td>
#       <td>2.088958</td>
#       <td>0.331975</td>
#       <td>04:18</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.766315</td>
#       <td>0.420213</td>
#       <td>1.898245</td>
#       <td>0.363057</td>
#       <td>04:19</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.556644</td>
#       <td>0.481677</td>
#       <td>1.898235</td>
#       <td>0.510573</td>
#       <td>04:19</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.619441</td>
#       <td>0.471644</td>
#       <td>29.310412</td>
#       <td>0.134522</td>
#       <td>04:19</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.404806</td>
#       <td>0.527933</td>
#       <td>1.227563</td>
#       <td>0.607898</td>
#       <td>04:19</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.222378</td>
#       <td>0.593938</td>
#       <td>1.083556</td>
#       <td>0.650191</td>
#       <td>04:20</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1
='C:\\Users\\iamab\\Downloads\\imagenette2-160\\wandb\\run-20200707_140942-1xqv2t5t\\bestmodel.pth'>
# Loaded best saved model from C:\Users\iamab\Downloads\imagenette2-160\wandb\run-20200707_140942-1xqv2t5t\bestmodel.pth

# %% [markdown]
# ## Learning with Lookahead

# %%
wandb.init(name = 'with_lookahead', project = 'learning',entity = 'a_bhimanyu',
           dir = 'C:/Users/iamab/Downloads/imagenette2-160')
# Out:
#                 Logging results to <a href="https://wandb.com" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://app.wandb.ai/a_bhimanyu/learning" target="_blank">https://app.wandb.ai/a_bhimanyu/learning</a><br/>
#                 Run page: <a href="https://app.wandb.ai/a_bhimanyu/learning/runs/1bhad4vu" target="_blank">https://app.wandb.ai/a_bhimanyu/learning/runs/1bhad4vu</a><br/>
# W&B Run: https://app.wandb.ai/a_bhimanyu/learning/runs/1bhad4vu

# %%
opt = partial(StatefulOptimizer, 
              steppers = [momentum_step, weight_decay, lookahead_step], 
              stats = [AverageGrad(), Step(), LookAheadStat()], 
              lr =0.01,wd = 1e-04)

learn = Learner(model, data, loss_func=F.cross_entropy, opt_func=opt, cb_funcs=cbfs)

# %%
learn.fit(30)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='30', style='width:300px; height:20px; vertical-align: middle;'></progress>
#
#     </div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>train_accuracy</th>
#       <th>valid_loss</th>
#       <th>valid_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.115369</td>
#       <td>0.268772</td>
#       <td>2.125403</td>
#       <td>0.310573</td>
#       <td>05:02</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.041752</td>
#       <td>0.358010</td>
#       <td>2.220892</td>
#       <td>0.303185</td>
#       <td>04:24</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.914470</td>
#       <td>0.375436</td>
#       <td>5.168261</td>
#       <td>0.381146</td>
#       <td>04:25</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.580367</td>
#       <td>0.460450</td>
#       <td>1.780599</td>
#       <td>0.399490</td>
#       <td>04:24</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.416302</td>
#       <td>0.521597</td>
#       <td>1.253119</td>
#       <td>0.585732</td>
#       <td>04:26</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.294021</td>
#       <td>0.567959</td>
#       <td>1.288084</td>
#       <td>0.601019</td>
#       <td>04:23</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.168160</td>
#       <td>0.610307</td>
#       <td>1.256645</td>
#       <td>0.589299</td>
#       <td>04:25</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1.068681</td>
#       <td>0.645580</td>
#       <td>1.109056</td>
#       <td>0.648917</td>
#       <td>04:24</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.010166</td>
#       <td>0.662478</td>
#       <td>1.064958</td>
#       <td>0.656051</td>
#       <td>04:26</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.954699</td>
#       <td>0.680008</td>
#       <td>0.921343</td>
#       <td>0.696306</td>
#       <td>04:24</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.887726</td>
#       <td>0.704087</td>
#       <td>2.333209</td>
#       <td>0.722803</td>
#       <td>04:26</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.831542</td>
#       <td>0.726053</td>
#       <td>0.913040</td>
#       <td>0.709809</td>
#       <td>04:25</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.788188</td>
#       <td>0.743584</td>
#       <td>0.823299</td>
#       <td>0.730955</td>
#       <td>04:26</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.710828</td>
#       <td>0.763861</td>
#       <td>0.769193</td>
#       <td>0.753376</td>
#       <td>04:23</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.676515</td>
#       <td>0.779491</td>
#       <td>10.657950</td>
#       <td>0.748025</td>
#       <td>04:24</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.631674</td>
#       <td>0.788256</td>
#       <td>0.829356</td>
#       <td>0.766624</td>
#       <td>04:24</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.589030</td>
#       <td>0.806104</td>
#       <td>0.688800</td>
#       <td>0.783439</td>
#       <td>04:25</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.544801</td>
#       <td>0.820678</td>
#       <td>4.164700</td>
#       <td>0.765095</td>
#       <td>04:23</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.508958</td>
#       <td>0.831133</td>
#       <td>0.654146</td>
#       <td>0.793885</td>
#       <td>04:24</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.449358</td>
#       <td>0.852255</td>
#       <td>0.685908</td>
#       <td>0.780637</td>
#       <td>04:24</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.427022</td>
#       <td>0.858802</td>
#       <td>4.217606</td>
#       <td>0.791592</td>
#       <td>04:26</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.400633</td>
#       <td>0.868624</td>
#       <td>11.360280</td>
#       <td>0.803567</td>
#       <td>04:24</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.363297</td>
#       <td>0.882564</td>
#       <td>0.677205</td>
#       <td>0.796943</td>
#       <td>04:25</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.340361</td>
#       <td>0.888373</td>
#       <td>0.634960</td>
#       <td>0.814522</td>
#       <td>04:24</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.286515</td>
#       <td>0.907910</td>
#       <td>0.643896</td>
#       <td>0.806369</td>
#       <td>04:25</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.263810</td>
#       <td>0.915725</td>
#       <td>0.668758</td>
#       <td>0.814777</td>
#       <td>04:24</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.247240</td>
#       <td>0.921639</td>
#       <td>0.665306</td>
#       <td>0.822420</td>
#       <td>04:23</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.216079</td>
#       <td>0.932200</td>
#       <td>0.673528</td>
#       <td>0.827516</td>
#       <td>04:26</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.212317</td>
#       <td>0.933678</td>
#       <td>0.690371</td>
#       <td>0.814777</td>
#       <td>04:25</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.217997</td>
#       <td>0.932728</td>
#       <td>0.681537</td>
#       <td>0.817070</td>
#       <td>04:24</td>
#     </tr>
#   </tbody>
# </table>
# C:\Users\iamab\Anaconda3\lib\site-packages\wandb\compat\tempfile.py:64: UserWarning: Couldn't remove temp directory C:\Users\iamab\AppData\Local\Temp\tmp8j3id2fjwandb
#   _warnings.warn("Couldn't remove temp directory %s" % name)
# Better model found at epoch 0 with valid_loss value: 2.2413508892059326.
# Saving model state at <_io.BufferedWriter name='C:\\Users\\iamab\\Downloads\\imagenette2-160\\wandb\\run-20200708_152442-1bhad4vu\\bestmodel.pth'>
# Better model found at epoch 1 with valid_loss value: 2.1611359119415283.
# Saving model state at <_io.BufferedWriter name='C:\\Users\\iamab\\Downloads\\imagenette2-160\\wandb\\run-20200708_152442-1bhad4vu\\bestmodel.pth'>
# Better model found at epoch 2 with valid_loss value: 1.6858024597167969.
# Saving model state at <_io.BufferedWriter name='C:\\Users\\iamab\\Downloads\\imagenette2-160\\wandb\\run-20200708_152442-1bhad4vu\\bestmodel.pth'>
# Better model found at epoch 3 with valid_loss value: 1.576483964920044.
# Saving model state at <_io.BufferedWriter name='C:\\Users\\iamab\\Downloads\\imagenette2-160\\wandb\\run-20200708_152442-1bhad4vu\\bestmodel.pth'>
# Better model found at epoch 5 with valid_loss value: 1.097199559211731.
# Saving model state at <_io.BufferedWriter name='C:\\Users\\iamab\\Downloads\\imagenette2-160\\wandb\\run-20200708_152442-1bhad4vu\\bestmodel.pth'>
# Better model found at epoch 17 with valid_loss value: 0.9911053776741028.
# Saving model state at <_io.BufferedWriter name='C:\\Users\\iamab\\Downloads\\imagenette2-160\\wandb\\run-20200708_152442-1bhad4vu\\bestmodel.pth'>
# Loading model state from <_io.BufferedReader name='C:\\Users\\iamab\\Downloads\\imagenette2-160\\wandb\\run-20200708_152442-1bhad4vu\\bestmodel.pth'>
# Loaded best saved model from C:\Users\iamab\Downloads\imagenette2-160\wandb\run-20200708_152442-1bhad4vu\bestmodel.pth
